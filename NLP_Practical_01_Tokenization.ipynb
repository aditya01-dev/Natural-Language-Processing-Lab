# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya01-dev/Natural-Language-Processing-Lab/blob/main/NLP_Practical_01_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Natural Language Processing Laboratory

## Practical 1: Tokenization of Sentences and Words using NLTK and spaCy
#Name: Aditya Kumar Singh (2401331520018)
#Course: B.Tech CSE (Artificial Intelligence)
#Subject: Natural Language Processing Laboratory
#Practical No.: 1
#CO1

# %%
## Objective

#To perform sentence tokenization and word tokenization on a given text using NLTK and spaCy.

# %%
# !pip install -q spacy

# %%
import nltk
import spacy

# Download required NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Download English spaCy model
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 43.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
Natural Language Processing is a branch of Artificial Intelligence.
It helps computers understand human language.
NLT​​K and spaCy are popular NLP libraries.
"""

print(text)
# Out:
# Natural Language Processing is a branch of Artificial Intelligence.
# It helps computers understand human language.
# NLT​​K and spaCy are popular NLP libraries.

# %%
nltk_sentences = sent_tokenize(text)

print("Sentences using NLTK:")
for i, sentence in enumerate(nltk_sentences, 1):
    print(f"{i}. {sentence}")
# Out:
# Sentences using NLTK:
# 1.
# Natural Language Processing is a branch of Artificial Intelligence.
# 2. It helps computers understand human language.
# 3. NLT​​K and spaCy are popular NLP libraries.

# %%
nltk_words = word_tokenize(text)

print("Words using NLTK:")
print(nltk_words)
# Out:
# Words using NLTK:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'NLT\u200b\u200bK', 'and', 'spaCy', 'are', 'popular', 'NLP', 'libraries', '.']

# %%
doc = nlp(text)

print("Sentences using spaCy:")
for i, sentence in enumerate(doc.sents, 1):
    print(f"{i}. {sentence.text}")
# Out:
# Sentences using spaCy:
# 1.
# Natural Language Processing is a branch of Artificial Intelligence.
#
# 2. It helps computers understand human language.
#
# 3. NLT​​K and spaCy are popular NLP libraries.

# %%
spacy_words = [token.text for token in doc]

print("Words using spaCy:")
print(spacy_words)
# Out:
# Words using spaCy:
# ['\n', 'Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', '\n', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', '\n', 'NLT\u200b\u200bK', 'and', 'spaCy', 'are', 'popular', 'NLP', 'libraries', '.', '\n']

# %%
print("Comparison")
print("-" * 40)

print(f"NLTK sentence count  : {len(nltk_sentences)}")
print(f"spaCy sentence count : {len(list(doc.sents))}")

print(f"\nNLTK word count      : {len(nltk_words)}")
print(f"spaCy word count     : {len(spacy_words)}")
# Out:
# Comparison
# ----------------------------------------
# NLTK sentence count  : 3
# spaCy sentence count : 3
#
# NLTK word count      : 25
# spaCy word count     : 29

# %%
## Result

#The given text was successfully tokenized into sentences and words using both NLTK and spaCy.

#NLTK and spaCy were used to demonstrate sentence-level and word-level tokenization.
